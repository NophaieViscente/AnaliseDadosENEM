# %% [markdown]
# <a href="https://colab.research.google.com/github/NophaieViscente/colab/blob/main/Analisando_Dados_da_Educa%C3%A7%C3%A3o_ENEM_SC_Mesorregi%C3%A3o_Serrana_%7C_Microrregi%C3%A3o_de_Curitibanos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importando as bibliotecas 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# Carregando os dados do ENEM já filtrado por estado.
dadosSC2015 = pd.read_csv('/content/drive/MyDrive/microdados_enem_sc_2015.csv')
dadosSC2016 = pd.read_csv('/content/drive/MyDrive/microdados_enem_sc_2016.csv')
dadosSC2017 = pd.read_csv('/content/drive/MyDrive/microdados_enem_sc_2017.csv')
dadosSC2018 = pd.read_csv('/content/drive/MyDrive/microdados_enem_sc_2018.csv') 
dadosSC2019 = pd.read_csv('/content/drive/MyDrive/microdados_enem_SC_2019.csv')

# %%
# Removendo dados de 2015 os quais não vamos utilizar .
dados_remover2015 = dadosSC2015.loc[dadosSC2015['TP_COR_RACA'] == 6]
dadosSC2015.drop(dados_remover2015.index,inplace=True)

# %%
# Criando lista com o nome das cidades das microrregiões. 
regiao_serrana = ['Abdon Batista','Brunópolis','Campos Novos','Curitibanos','Frei Rogério','Monte Carlo',
'Ponte Alta','Ponte Alta do Norte','Santa Cecília','São Cristóvão do Sul','Vargem','Zortéa']

# %%
# Criando novos datasets somente com as cidades da microrregião serrana.
dados_regiao_serrana2015 = pd.DataFrame()
dados_regiao_serrana2016 = pd.DataFrame()
dados_regiao_serrana2017 = pd.DataFrame()
dados_regiao_serrana2018 = pd.DataFrame()
dados_regiao_serrana2019 = pd.DataFrame()
for cidade in regiao_serrana :
  dados_regiao_serrana2015 = dados_regiao_serrana2015.append(dadosSC2015[dadosSC2015['NO_MUNICIPIO_RESIDENCIA'] == cidade])
  dados_regiao_serrana2016 = dados_regiao_serrana2016.append(dadosSC2016[dadosSC2016['NO_MUNICIPIO_RESIDENCIA'] == cidade])
  dados_regiao_serrana2017 = dados_regiao_serrana2017.append(dadosSC2017[dadosSC2017['NO_MUNICIPIO_RESIDENCIA'] == cidade])
  dados_regiao_serrana2018 = dados_regiao_serrana2018.append(dadosSC2018[dadosSC2018['NO_MUNICIPIO_RESIDENCIA'] == cidade])
  dados_regiao_serrana2019 = dados_regiao_serrana2019.append(dadosSC2019[dadosSC2019['NO_MUNICIPIO_RESIDENCIA'] == cidade])

# %%
fig2, ax2 = plt.subplots(figsize=(12.5,6))
participantes_por_Raca2015 = dados_regiao_serrana2015['TP_COR_RACA'].value_counts().sort_index()
# Criando dicionário para a substituição dos números pela categoria . 
dicionarioRacas = {0 : 'Não declarado', 1 : 'Branca',2 : 'Preta', 3 :'Parda',4:'Amarela',5:'Indígena'}
# Retirando as linhas de borda . 
for axis in ['top', 'right', 'left']:
   ax2.spines[axis].set_color(None)
for indice, valor in enumerate(participantes_por_Raca2015) :
  indice = dicionarioRacas[indice]
  fig2 = plt.bar(indice,valor,width=0.95,edgecolor='white',linewidth=0.95)
  ax2.text(x=indice ,y=valor, s=valor ,horizontalalignment='center',
          verticalalignment='bottom',fontdict={'fontsize':12.25})
plt.title('Quantidade de candidatos ENEM SC 2015 por declaração racial - Microrregião de Curitibanos',fontdict={'fontsize': 17.5})
# Out:
# Text(0.5, 1.0, 'Quantidade de candidatos ENEM SC 2015 por declaração racial - Microrregião de Curitibanos')

# %%
fig3, ax3 = plt.subplots(figsize=(12.5,6))
participantes_por_Raca2016 = dados_regiao_serrana2016['TP_COR_RACA'].value_counts().sort_index()
# Criando dicionário para a substituição dos números pela categoria . 
dicionarioRacas = {0 : 'Não declarado', 1 : 'Branca',2 : 'Preta', 3 :'Parda',4:'Amarela',5:'Indígena'}
# Retirando as linhas de borda . 
for axis in ['top', 'right', 'left']:
   ax3.spines[axis].set_color(None)
for indice, valor in enumerate(participantes_por_Raca2016) :
  indice = dicionarioRacas[indice]
  fig3 = plt.bar(indice,valor,width=0.95,edgecolor='white',linewidth=0.95)
  ax3.text(x=indice ,y=valor, s=valor ,horizontalalignment='center',
          verticalalignment='bottom',fontdict={'fontsize':12.25})
plt.title('Quantidade de candidatos ENEM SC 2016 por declaração racial - Microrregião Curitibanos',fontdict={'fontsize': 17.5})
# Out:
# Text(0.5, 1.0, 'Quantidade de candidatos ENEM SC 2016 por declaração racial - Microrregião Curitibanos')

# %%
fig4, ax4 = plt.subplots(figsize=(12.5,6))
participantes_por_Raca2017 = dados_regiao_serrana2017['TP_COR_RACA'].value_counts().sort_index()
# Criando dicionário para a substituição dos números pela categoria . 
dicionarioRacas = {0 : 'Não declarado', 1 : 'Branca',2 : 'Preta', 3 :'Parda',4:'Amarela',5:'Indígena'}
# Retirando as linhas de borda . 
for axis in ['top', 'right', 'left']:
   ax4.spines[axis].set_color(None)
for indice, valor in enumerate(participantes_por_Raca2017) :
  indice = dicionarioRacas[indice]
  fig4 = plt.bar(indice,valor,width=0.95,edgecolor='white',linewidth=0.95)
  ax4.text(x=indice ,y=valor, s=valor ,horizontalalignment='center',
          verticalalignment='bottom',fontdict={'fontsize':12.25})
plt.title('Quantidade de candidatos ENEM SC 2017 por declaração racial - Microrregião de Curitibanos',fontdict={'fontsize': 17.5})
# Out:
# Text(0.5, 1.0, 'Quantidade de candidatos ENEM SC 2017 por declaração racial - Microrregião de Curitibanos')

# %%
fig5, ax5 = plt.subplots(figsize=(12.5,6))
participantes_por_Raca2018 = dados_regiao_serrana2018['TP_COR_RACA'].value_counts().sort_index()
# Criando dicionário para a substituição dos números pela categoria . 
dicionarioRacas = {0 : 'Não declarado', 1 : 'Branca',2 : 'Preta', 3 :'Parda',4:'Amarela',5:'Indígena'}
# Retirando as linhas de borda . 
for axis in ['top', 'right', 'left']:
   ax5.spines[axis].set_color(None)
for indice, valor in enumerate(participantes_por_Raca2018) :
  indice = dicionarioRacas[indice]
  fig5 = plt.bar(indice,valor,width=0.95,edgecolor='white',linewidth=0.95)
  ax5.text(x=indice ,y=valor, s=valor ,horizontalalignment='center',
          verticalalignment='bottom',fontdict={'fontsize':12.25})
plt.title('Quantidade de candidatos ENEM SC 2018 por declaração racial - Microrregião de Curitibanos',fontdict={'fontsize': 17.5})
# Out:
# Text(0.5, 1.0, 'Quantidade de candidatos ENEM SC 2018 por declaração racial - Microrregião de Curitibanos')

# %%
fig6, ax6 = plt.subplots(figsize=(12.5,6))
participantes_por_Raca2019 = dados_regiao_serrana2019['TP_COR_RACA'].value_counts().sort_index()
# Criando dicionário para a substituição dos números pela categoria . 
dicionarioRacas = {0 : 'Não declarado', 1 : 'Branca',2 : 'Preta', 3 :'Parda',4:'Amarela',5:'Indígena'}
# Retirando as linhas de borda . 
for axis in ['top', 'right', 'left']:
   ax6.spines[axis].set_color(None)
for indice, valor in enumerate(participantes_por_Raca2019) :
  indice = dicionarioRacas[indice]
  fig6 = plt.bar(indice,valor,width=0.95,edgecolor='white',linewidth=0.95)
  ax6.text(x=indice ,y=valor, s=valor ,horizontalalignment='center',
          verticalalignment='bottom',fontdict={'fontsize':12.25})
plt.title('Quantidade de candidatos ENEM SC 2019 por declaração racial - Microrregião de Curitibanos',fontdict={'fontsize': 17.5})
# Out:
# Text(0.5, 1.0, 'Quantidade de candidatos ENEM SC 2019 por declaração racial - Microrregião de Curitibanos')

# %%
dados_regiao_serrana = pd.concat([dados_regiao_serrana2015,dados_regiao_serrana2016,dados_regiao_serrana2017,
                                 dados_regiao_serrana2018,dados_regiao_serrana2019])
dados_regiao_serrana.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'IN_ESTUDA_CLASSE_HOSPITALAR', 'IN_TREINEIRO', 'CO_ESCOLA',
#        'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC',
#        'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC',
#        'NU_IDADE', 'TP_SEXO', 'TP_NACIONALIDADE',
#        'CO_MUNICIPIO_NASCIMENTO', 'NO_MUNICIPIO_NASCIMENTO',
#        'CO_UF_NASCIMENTO', 'SG_UF_NASCIMENTO', 'TP_ST_CONCLUSAO',
#        'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'TP_ESTADO_CIVIL',
#        'TP_COR_RACA', 'IN_BAIXA_VISAO', 'IN_CEGUEIRA', 'IN_SURDEZ',
#        'IN_DEFICIENCIA_AUDITIVA', 'IN_SURDO_CEGUEIRA',
#        'IN_DEFICIENCIA_FISICA', 'IN_DEFICIENCIA_MENTAL',
#        'IN_DEFICIT_ATENCAO', 'IN_DISLEXIA', 'IN_GESTANTE', 'IN_LACTANTE',
#        'IN_IDOSO', 'IN_DISCALCULIA', 'IN_AUTISMO', 'IN_VISAO_MONOCULAR',
# ...

# %%
# Filtrando os candidatos por declaração de raça.
participantes_por_Raca = dados_regiao_serrana['TP_COR_RACA'].value_counts().sort_index()
# Criando dicionário para a substituição dos números pela categoria . 
dicionarioRacas = {0 : 'Não declarado', 1 : 'Branca',2 : 'Preta', 3 :'Parda',4:'Amarela',5:'Indígena'}
# Construindo o gráfico
fig, ax = plt.subplots(figsize=(12.5,6))
# Retirando as linhas de borda . 
for axis in ['top', 'right', 'left']:
   ax.spines[axis].set_color(None)
# Capturando o indice para ser substituído por uma categoria;
# Capturando valor para alocar em cima das barras do gráfico.
for indice, valor in enumerate(participantes_por_Raca) :
  indice = dicionarioRacas[indice]
  fig = plt.bar(indice,valor,width=0.95,edgecolor='white',linewidth=0.95)
  ax.text(x=indice ,y=valor, s=valor ,horizontalalignment='center',
          verticalalignment='bottom',fontdict={'fontsize':12.25})
plt.title('Quantidade de candidatos ENEM SC 2015/2019 por declaração racial - Microrregião de Curitibanos',
          fontdict={'fontsize': 17.5,'fontweight':'semibold'})
plt.ylabel('QUANTIDADE')
plt.show()

# %%
#Capturando os dados das notas das provas e colocando em uma variável chamada provas
provas = ['NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_MT','NU_NOTA_LC','NU_NOTA_REDACAO']
# Atribuindo a soma das notas das provas de cada candidato da amostra e adicionando mais uma coluna ao dataframe 'dados_regiao_serrana' com a nota total de cada candidato.
dados_regiao_serrana['NU_NOTA_TOTAL'] = dados_regiao_serrana[provas].sum(axis=1)
# Alocando em um novo dataset sem as notas zero 
dados_rs_sem_nota_zero = dados_regiao_serrana.query('NU_NOTA_TOTAL > 0')
dados_rs_sem_nota_zero['NU_NOTA_TOTAL'].groupby(dados_rs_sem_nota_zero['TP_COR_RACA']).mean()
# Out:
# TP_COR_RACA
# 0    2478.693293
# 1    2544.023141
# 2    2421.418182
# 3    2435.174755
# 4    2565.319531
# 5    2278.711765
# Name: NU_NOTA_TOTAL, dtype: float64

# %%
fig8, ax8 = plt.subplots(figsize=(25,9.5))
for axis in ['top', 'right', 'left']:
   ax8.spines[axis].set_color(None)
sns.barplot(data=dados_regiao_serrana,x='NU_ANO',y='NU_NOTA_TOTAL',hue='TP_COR_RACA',palette='brg',ci=None)
plt.legend(['Não Declarada','Branca','Preta','Parda','Amarela','Indígena'],fontsize='large',loc='best')
plt.title('Nota Média Total dos Candidatos por Ano e por declaração racial',fontdict={'fontsize':21.5,
                                                                                      'fontweight':'semibold'})
plt.ylabel('NOTA TOTAL',fontdict={'fontsize': 15,'fontweight':'semibold'})
plt.xlabel('ANO',fontdict={'fontsize':15,'fontweight':'semibold'})
for i in range(0,3000,500):
  plt.yticks([i].append(i))
label=['2015','2016','2017','2018','2019']
plt.xticks(ticks=range(0,len(label)),labels=label)
plt.tick_params(labelsize=15)
plt.show()

# %%
# Criando dicionário para personalizar fontes
dicionarioFonte = {'fontsize':13.7,'weight':'semibold'}
# Gerando a figura e os eixos .
fig9 , ax9 = plt.subplots(figsize=(20,6.3))
# Eliminando as bordas do gráfico
for axis in ['top', 'right', 'left']:
   ax9.spines[axis].set_color(None)
# Renomeando os 'labels' dos eixos.
plt.xlabel('NOTA TOTAL',fontdict=dicionarioFonte)
plt.ylabel('Quantidade',fontdict=dicionarioFonte)
# Fazendo o cálculo da mediana para traças a linha vertical
mediana_masculino = dados_rs_sem_nota_zero.query('TP_SEXO == "M"')['NU_NOTA_TOTAL'].median()
mediana_feminino = dados_rs_sem_nota_zero.query('TP_SEXO == "F"')['NU_NOTA_TOTAL'].median()
moda_feminino = dados_rs_sem_nota_zero.query('TP_SEXO == "F"')['NU_NOTA_TOTAL'].mode()
moda_masculino = dados_rs_sem_nota_zero.query('TP_SEXO == "M"')['NU_NOTA_TOTAL'].mode()
# Traçando a linha vertical para as medianas .
plt.axvline(mediana_masculino,ls='dashdot',color='blue',lw=2.025)
plt.axvline(mediana_feminino,ls='dotted',color='red',lw=2.025)
# Plotando o gráfico . 
sns.histplot(dados_rs_sem_nota_zero,x = 'NU_NOTA_TOTAL',hue='TP_SEXO',kde=True,element='poly',
             palette='Dark2_r',stat='count')
# Escrevendo a legenda . 
plt.legend(['Mediana Nota Total Sexo Masculino','Mediana Nota Total Sexo Feminino','Sexo Masculino','Sexo Feminino'],
           fontsize=12.5,loc='best')
# Colocando o título no gráfico. 
plt.title('Quantidade de Candidatos por Nota Total (Somatório de todas as notas)',fontdict={'family':'Arial black','fontsize': 20,'fontweight':'semibold'})
plt.show()
# Out:
# findfont: Font family ['Arial black'] not found. Falling back to DejaVu Sans.

# %%
dicionarioRenda = {'A':'Sem Renda', 'B':'Até 998,00','C':'De 998,00 até 1996,00',
                  'D':'De 998,00 até R$ 1996,00','E':'De 1996,00 até 2994,00',
                  'F':'De 1996,00 até R$ 2994,00','G':'De 2994,00 até 5988,00','H':'De 2994,00 até 5988,00',
                  'I':'De 2994,00 até R$ 5988,00','J':'De 5988,00 até 8982,00','K':'De 5988,00 até 8982,00',
                  'L':'De 5988,00 até R$ 8982,00','M':'De 8982,00 até 11976,00','N':'De 8982,00 até 11976,00',
                  'O':'De 11976,01 até 19960,00','P':'De 11976,01 até 19960,00','Q':'Mais de 19960,00'}
dados_rs_sem_nota_zero['Q006'] = dados_rs_sem_nota_zero['Q006'].replace(dicionarioRenda)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
dicionario_acesso_internet = {'A' : 'Não tem acesso a internet em casa','B':'Tem acesso de internet em casa'}
dados_rs_sem_nota_zero['Q025'] = dados_rs_sem_nota_zero['Q025'].replace(dicionario_acesso_internet)
treineiro_renda = dados_rs_sem_nota_zero.query('IN_TREINEIRO == 1')['Q025'].value_counts()
nao_treineiro_renda = dados_rs_sem_nota_zero.query('IN_TREINEIRO == 0')['Q025'].value_counts()
treineiro_renda.plot(kind='barh',color='purple',alpha=.8,figsize=(15,8))
nao_treineiro_renda.plot(kind='barh',color='red',alpha=.4,figsize=(15,8))
plt.legend(['Treineiro','Não Treineiro'],fontsize='x-large')
plt.title('Treineiros e Não Treineiros com e sem acesso a internet em casa.',fontdict={'fontsize':20,'fontweight':'semibold'})
plt.xlabel('Quantidade de Candidatos',fontdict={'fontsize':14})
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plt.figure(figsize=(18,9.3))
sns.boxplot(data=dados_rs_sem_nota_zero,x='NU_NOTA_TOTAL',y='Q006',orient='h',palette='magma')
plt.ylabel('RENDA FAMILIAR',fontdict={'fontsize':15,'fontweight':'semibold'})
plt.xlabel('NOTA TOTAL',fontdict={'fontsize':15,'fontweight':'semibold'})
plt.show()

# %%
# Carregando dados do IBGE para poder usar na análise do ENEM
ibge = pd.read_csv('/content/drive/MyDrive/IBGE.csv',sep=';',encoding='ISO-8859-1')
# Criando lista para filtrar pelos municipios da região serrana, microrregião de Curitibanos
listaMunicipiosIBGE = [4200051, 4202875, 4203600, 4204806, 4205555, 4211058, 4213302,
       4213351, 4215505, 4219150, 4219853, 4216057]
# Verificando o DataFrame do IBGE com todos os dados de SC .
ibge
# Out:
#             MUNICIPIO  CODIGO_MUNICIPIO  ... DESPESAS_EMPENHADASx1000 PIB_PER_CAPTA
# 0       Abdon Batista           4200051  ...              18399,70671      24517,73
# 1        Abelardo Luz           4200101  ...              54531,83536      39108,44
# 2          Agrolândia           4200200  ...              28123,29815      23224,16
# 3          Agronômica           4200309  ...               17786,6489      29394,91
# 4           Água Doce           4200408  ...              29718,55841       43501,9
# ..                ...               ...  ...                      ...           ...
# 290           Xanxerê           4219507  ...              113122,0143      33864,92
# 291         Xavantina           4219606  ...              19119,64225      54550,94
# 292             Xaxim           4219705  ...              70477,21407      33345,93
# 293            Zortéa           4219853  ...               16591,3106      21389,69
# ...

# %%
# Criando DataFrame para receber os dados do IBGE da Microrregião de Curitibanos.
dados_IBGE_regiao_serrana = pd.DataFrame()
# Alocando os dados no DataFrame
for municipio in listaMunicipiosIBGE :
  dados_IBGE_regiao_serrana = dados_IBGE_regiao_serrana.append(ibge[ibge['CODIGO_MUNICIPIO'] == municipio])

# %%
# Verificando o DataFrame
dados_IBGE_regiao_serrana
# Out:
#                 MUNICIPIO  ...  PIB_PER_CAPTA
# 0           Abdon Batista  ...       24517,73
# 46             Brunópolis  ...       32851,48
# 56           Campos Novos  ...       54233,53
# 77            Curitibanos  ...       35989,53
# 91           Frei Rogério  ...       23743,48
# 164           Monte Carlo  ...       16172,78
# 200            Ponte Alta  ...       24218,32
# 201   Ponte Alta do Norte  ...       33833,93
# 228         Santa Cecília  ...       28120,98
# 284                Vargem  ...       24351,38
# 293                Zortéa  ...       21389,69
# 240  São Cristóvão do Sul  ...       28867,32
#
# [12 rows x 13 columns]

# %%
# Retirando as vírgulas e colocando ponto nas Strings IDHM
dados_IBGE_regiao_serrana['IDHM'] = dados_IBGE_regiao_serrana['IDHM'].apply(lambda x : float(str(x).replace(',','.')))
dados_completos_ENEM_IBGE = pd.merge(dados_rs_sem_nota_zero, dados_IBGE_regiao_serrana, 
                                     how='left',left_on=['CO_MUNICIPIO_RESIDENCIA'],right_on=['CODIGO_MUNICIPIO'])

# %%
fig10, ax10 = plt.subplots(figsize=(20,11))
for axis in ['top', 'right', 'left']:
   ax10.spines[axis].set_color(None)
sns.lineplot(data=dados_completos_ENEM_IBGE,x='NO_MUNICIPIO_RESIDENCIA',y='IDHM',marker='o',markersize=11,
             lw=2.5)
ax10.annotate('IDH Brasil',xy=(6,0.710),xycoords='data',xytext=(6.8,0.73),arrowprops=dict(facecolor='red', shrink=0.05),
              horizontalalignment='right', verticalalignment='top',)
plt.grid(True,ls='--')
plt.axhline(0.710,ls='-.',color='r')
plt.title('IDHM Microrregião de Curitibanos (Indice de Desenvolvimento Humano Por Municipio)',fontdict={'fontsize':20,'fontweight':'semibold'})
plt.xticks(rotation=45)
plt.xlabel('MUNICIPIO',fontdict={'fontsize':15,'fontweight':'semibold'})
plt.ylabel('IDH',fontdict={'fontsize':15,'fontweight':'semibold'})
plt.tick_params(labelsize=13.5)
plt.show()

# %%
fig11, ax11 = plt.subplots(figsize=(20,8))
dados_filtrados_nota_total = dados_completos_ENEM_IBGE.filter(items=['NO_MUNICIPIO_RESIDENCIA','NU_ANO','NU_NOTA_TOTAL'])\
                                .groupby(['NO_MUNICIPIO_RESIDENCIA','NU_ANO']).mean().sort_values(by='NU_NOTA_TOTAL')
sns.lineplot(data=dados_filtrados_nota_total,x='NU_ANO',y='NU_NOTA_TOTAL',hue='NO_MUNICIPIO_RESIDENCIA',lw=3,marker='s',
             markersize=11)
plt.legend(bbox_to_anchor=(1.05,1),fontsize='xx-large')
